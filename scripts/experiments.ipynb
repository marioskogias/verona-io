# %%
import matplotlib.pyplot as plt
import numpy as np

RES_DIR = "C:\\Users\\t-makog\\Code\\verona-io\\results\\processed"

cfgs = [ 
        "verona-static-fixed", 
        "verona-floating-many-fixed", 
        "verona-floating-many-unfair-fixed",
        "verona-token-fixed"]

# %%
for c in cfgs:
    fname = "{}\\{}.txt".format(RES_DIR, c)
    data = np.loadtxt(fname)
    x = data[:,0] / 1000
    y = data[:, 11]
    #y = data[:, 3]
    plt.plot(x, y, label=c)
plt.legend()
plt.xlabel("kRPS")
plt.ylabel("99-th latency (us)")
plt.ylim([0, 5000])
plt.show()
